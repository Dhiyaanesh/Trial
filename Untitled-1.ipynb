# %%
fruits= ("apple", "banana", "cherry")
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %%
fruits= ("orange", "banana", "cherry")
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# orange
# banana
# cherry

# %%
x = "Python"
y = "is"
z = "awesome"
print(x, y, z)
# Out:
# Python is awesome

# %%
x = "Python"
y = "is"
z = "awesome"
print(x + y + z)
# Out:
# Pythonisawesome

# %%
x = "Python "
y = "is "
z = "awesome"
print(x + y + z)
# Out:
# Python is awesome

# %%
x=5; y=6
print (x+y)
# Out:
# 11

# %%
x= 5
y = 'Awesome'
print(str(x), y)
# Out:
# 5 Awesome

# %%
x= 'cool'
def trial_func():
    print("Python is " + x)
trial_func()
# Out:
# Python is cool

# %%
x= 'cool'
def trial_func():
    x= 'awesome'
    print("Python is " + x)
trial_func()
# Out:
# Python is awesome

# %%
x= 'cool'
def trial_func():
    x= 'awesome'
    print("Python is " + x)
trial_func()
print("Python is " + x)
# Out:
# Python is awesome
# Python is cool

# %%
y= 'cool'
def trial_func():
    x= 'awesome and '
    print("Python is " + x + y)
trial_func()
# Out:
# Python is awesome and cool

# %%
x = 'awesome'
def trial_func():
    global x
    x= 'cool'
    print("Python is " + x)
trial_func()
# Out:
# Python is cool

# %%
x = 'awesome'
def trial_func():
    global x
    print("Python is " + x)
trial_func()
print("Python is " + x)
# Out:
# Python is awesome
# Python is awesome

# %%
x=5
y='john'
print(type(x))
# Out:
# <class 'int'>

# %%
x= True
print(type(x))
# Out:
# <class 'bool'>

# %%
x= b"Hello"; y= bytearray(5); z= memoryview(bytes(5))
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'bytes'>
# <class 'bytearray'>
# <class 'memoryview'>

# %%
x= memoryview(bytes(999))
print(x)
print(type(x))
# Out:
# ...
# <class 'memoryview'>

# %%
a= 1
b= 2.8
c= 1j
d= 1e3
e= -87.7e100
f= -3j
print (type(a), 'a')
print (type(b), 'b')
print (type(c), 'c')
print (type(d), 'd')
print (type(e), 'e')
print (type(f), 'f')
# Out:
# <class 'int'> a
# <class 'float'> b
# <class 'complex'> c
# <class 'float'> d
# <class 'float'> e
# <class 'complex'> f

# %%
x=5
y=2.9
z=1j
a= float(x)
b= int(y)
c= complex(x)
print(a)
print(b)
print(c)
print(type(a))
print(type(b))
print(type(c))
# Out:
# 5.0
# 2
# (5+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
x = 5
# Out:
#   Cell In[62], line 1
#     x=43h
#        ^
# SyntaxError: invalid decimal literal
